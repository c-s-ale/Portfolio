# %% [markdown]
# Taken from: https://www.kaggle.com/martinpiotte/bounding-box-model/data

# %%
import sys
import tensorflow.keras

# %%
with open('./input/cropping.txt', 'rt') as f: data = f.read().split('\n')[:-1]
data = [line.split(',') for line in data]
data = [(p,[(int(coord[i]),int(coord[i+1])) for i in range(0,len(coord),2)]) for p,*coord in data]
data[0] # Show an example: (picture-name, [coordinates])
# Out:
# ('88532e70.jpg',
#  [(195, 293),
#   (269, 115),
#   (868, 158),
#   (888, 170),
#   (641, 496),
#   (512, 546),
#   (321, 524)])

# %%
from PIL import Image as pil_image
from PIL.ImageDraw import Draw
from os.path import isfile

def expand_path(p):
    if isfile('./input/data/train/' + p): return './input/data/train/' + p
    if isfile('./input/data/test/' + p): return './input/data/test/' + p
    return p

def read_raw_image(p):
    return pil_image.open(expand_path(p))

def draw_dot(draw, x, y):
    draw.ellipse(((x-5,y-5),(x+5,y+5)), fill='red', outline='red')

def draw_dots(draw, coordinates):
    for x,y in coordinates: draw_dot(draw, x, y)

def bounding_rectangle(list):
    x0, y0 = list[0]
    x1, y1 = x0, y0
    for x,y in list[1:]:
        x0 = min(x0, x)
        y0 = min(y0, y)
        x1 = max(x1, x)
        y1 = max(y1, y)
    return x0,y0,x1,y1

filename,coordinates = data[0]
box = bounding_rectangle(coordinates)
img = read_raw_image(filename)
draw = Draw(img)
draw_dots(draw, coordinates)
draw.rectangle(box, outline='red')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1050x700 at 0x25F81374880>

# %%
# Define useful constants
img_shape  = (128,128,1)
anisotropy = 2.15

# %%
import random
import numpy as np
from scipy.ndimage import affine_transform
from tensorflow.keras.preprocessing.image import img_to_array

# Read an image as black&white numpy array
def read_array(p):
    img = read_raw_image(p).convert('L')
    return img_to_array(img)

def build_transform(rotation, shear, height_zoom, width_zoom, height_shift, width_shift):
    rotation        = np.deg2rad(rotation)
    shear           = np.deg2rad(shear)
    rotation_matrix = np.array([[np.cos(rotation), np.sin(rotation), 0], [-np.sin(rotation), np.cos(rotation), 0], [0, 0, 1]])
    shift_matrix    = np.array([[1, 0, height_shift], [0, 1, width_shift], [0, 0, 1]])
    shear_matrix    = np.array([[1, np.sin(shear), 0], [0, np.cos(shear), 0], [0, 0, 1]])
    zoom_matrix     = np.array([[1.0/height_zoom, 0, 0], [0, 1.0/width_zoom, 0], [0, 0, 1]])
    shift_matrix    = np.array([[1, 0, -height_shift], [0, 1, -width_shift], [0, 0, 1]])
    return np.dot(np.dot(rotation_matrix, shear_matrix), np.dot(zoom_matrix, shift_matrix))

# Compute the coordinate transformation required to center the pictures, padding as required.
def center_transform(affine, input_shape):
    hi, wi = float(input_shape[0]), float(input_shape[1])
    ho, wo = float(img_shape[0]), float(img_shape[1])
    top, left, bottom, right = 0, 0, hi, wi
    if wi/hi/anisotropy < wo/ho: # input image too narrow, extend width
        w     = hi*wo/ho*anisotropy
        left  = (wi-w)/2
        right = left + w
    else: # input image too wide, extend height
        h      = wi*ho/wo/anisotropy
        top    = (hi-h)/2
        bottom = top + h
    center_matrix   = np.array([[1, 0, -ho/2], [0, 1, -wo/2], [0, 0, 1]])
    scale_matrix    = np.array([[(bottom - top)/ho, 0, 0], [0, (right - left)/wo, 0], [0, 0, 1]])
    decenter_matrix = np.array([[1, 0, hi/2], [0, 1, wi/2], [0, 0, 1]])
    return np.dot(np.dot(decenter_matrix, scale_matrix), np.dot(affine, center_matrix))

# Apply an affine transformation to an image represented as a numpy array.
def transform_img(x, affine):
    matrix   = affine[:2,:2]
    offset   = affine[:2,2]
    x        = np.moveaxis(x, -1, 0)
    channels = [affine_transform(channel, matrix, offset, output_shape=img_shape[:-1], order=1,
                                 mode='constant', cval=np.average(channel)) for channel in x]
    return np.moveaxis(np.stack(channels, axis=0), 0, -1)

# Read an image for validation, i.e. without data augmentation.
def read_for_validation(p):
    x  = read_array(p)
    t  = np.array([[1, 0, 0], [0, 1, 0], [0, 0, 1]])
    t  = center_transform(t, x.shape)
    x  = transform_img(x, t)
    x -= np.mean(x, keepdims=True)
    x /= np.std(x, keepdims=True) + K.epsilon()
    return x,t 

# Read an image for training, i.e. including a random affine transformation
def read_for_training(p):
    x  = read_array(p)
    t  = build_transform(
            random.uniform(-5, 5),
            random.uniform(-5, 5),
            random.uniform(0.9, 1.0),
            random.uniform(0.9, 1.0),
            random.uniform(-0.05*img_shape[0], 0.05*img_shape[0]),
            random.uniform(-0.05*img_shape[1], 0.05*img_shape[1]))
    t  = center_transform(t, x.shape)
    x  = transform_img(x, t)
    x -= np.mean(x, keepdims=True)
    x /= np.std(x, keepdims=True) + K.epsilon()
    return x,t   

# Transform corrdinates according to the provided affine transformation
def coord_transform(list, trans):
    result = []
    for x,y in list:
        y,x,_ = trans.dot([y,x,1]).astype(int)
        result.append((x,y))
    return result

# %%
from sklearn.model_selection import train_test_split

train, val = train_test_split(data, test_size=200, random_state=1)
train += train
train += train
train += train
train += train
len(train),len(val)
# Out:
# (16000, 200)

# %%
import matplotlib.pyplot as plt
from tqdm import tqdm, tqdm_notebook
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import array_to_img
from numpy.linalg import inv as mat_inv

def show_whale(imgs, per_row=5):
    n         = len(imgs)
    rows      = (n + per_row - 1)//per_row
    cols      = min(per_row, n)
    fig, axes = plt.subplots(rows,cols, figsize=(24//per_row*cols,24//per_row*rows))
    for ax in axes.flatten(): ax.axis('off')
    for i,(img,ax) in enumerate(zip(imgs, axes.flatten())): ax.imshow(img.convert('RGB'))

val_a = np.zeros((len(val),)+img_shape,dtype=K.floatx()) # Preprocess validation images 
val_b = np.zeros((len(val),4),dtype=K.floatx()) # Preprocess bounding boxes
for i,(p,coords) in enumerate(tqdm_notebook(val)):
    img,trans      = read_for_validation(p)
    coords         = coord_transform(coords, mat_inv(trans))
    x0,y0,x1,y1    = bounding_rectangle(coords)
    val_a[i,:,:,:] = img
    val_b[i,0]     = x0
    val_b[i,1]     = y0
    val_b[i,2]     = x1
    val_b[i,3]     = y1

idx  = 1
img  = array_to_img(val_a[idx])
img  = img.convert('RGB')
draw = Draw(img)
draw.rectangle(val_b[idx], outline='red')
show_whale([read_raw_image(val[idx][0]), img], per_row=2)
# Out:
# C:\Users\scott\AppData\Local\Temp/ipykernel_34784/2592766456.py:17: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i,(p,coords) in enumerate(tqdm_notebook(val)):
#   0%|          | 0/200 [00:00<?, ?it/s]
# C:\Users\scott\AppData\Local\Temp/ipykernel_34784/685740430.py:78: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y,x,_ = trans.dot([y,x,1]).astype(np.int)

# %%
from tensorflow.keras.utils import Sequence

class TrainingData(Sequence):
    def __init__(self, batch_size=32):
        super(TrainingData, self).__init__()
        self.batch_size = batch_size
    def __getitem__(self, index):
        start = self.batch_size*index;
        end   = min(len(train), start + self.batch_size)
        size  = end - start
        a     = np.zeros((size,) + img_shape, dtype=K.floatx())
        b     = np.zeros((size,4), dtype=K.floatx())
        for i,(p,coords) in enumerate(train[start:end]):
            img,trans   = read_for_training(p)
            coords      = coord_transform(coords, mat_inv(trans))
            x0,y0,x1,y1 = bounding_rectangle(coords)
            a[i,:,:,:]  = img
            b[i,0]      = x0
            b[i,1]      = y0
            b[i,2]      = x1
            b[i,3]      = y1
        return a,b
    def __len__(self):
        return (len(train) + self.batch_size - 1)//self.batch_size

random.seed(1)
a, b = TrainingData(batch_size=5)[1]
img  = array_to_img(a[0])
img  = img.convert('RGB')
draw = Draw(img)
draw.rectangle(b[0], outline='red')
show_whale([read_raw_image(train[0][0]), img], per_row=2)
# Out:
# C:\Users\scott\AppData\Local\Temp/ipykernel_34784/685740430.py:78: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y,x,_ = trans.dot([y,x,1]).astype(np.int)

# %%
from tensorflow.keras import Input
from tensorflow.keras.layers import BatchNormalization, Concatenate, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.models import Model

def build_model(with_dropout=True):
    kwargs     = {'activation':'relu', 'padding':'same'}
    conv_drop  = 0.2
    dense_drop = 0.5
    inp        = Input(shape=img_shape)

    x = inp

    x = Conv2D(64, (9, 9), **kwargs)(x)
    x = Conv2D(64, (3, 3), **kwargs)(x)
    x = BatchNormalization()(x)
    if with_dropout: x = Dropout(conv_drop, noise_shape=(None, 1, 1, int(x.shape[-1])))(x)

    x = Conv2D(64, (2, 2), **kwargs, strides=2)(x)
    x = Conv2D(64, (3, 3), **kwargs)(x)
    x = Conv2D(64, (3, 3), **kwargs)(x)
    x = BatchNormalization()(x)
    if with_dropout: x = Dropout(conv_drop, noise_shape=(None, 1, 1, int(x.shape[-1])))(x)

    x = Conv2D(64, (2, 2), **kwargs, strides=2)(x)
    x = Conv2D(64, (3, 3), **kwargs)(x)
    x = Conv2D(64, (3, 3), **kwargs)(x)
    x = BatchNormalization()(x)
    if with_dropout: x = Dropout(conv_drop, noise_shape=(None, 1, 1, int(x.shape[-1])))(x)

    x = Conv2D(64, (2, 2), **kwargs, strides=2)(x)
    x = Conv2D(64, (3, 3), **kwargs)(x)
    x = Conv2D(64, (3, 3), **kwargs)(x)
    x = BatchNormalization()(x)
    if with_dropout: x = Dropout(conv_drop, noise_shape=(None, 1, 1, int(x.shape[-1])))(x)

    x = Conv2D(64, (2, 2), **kwargs, strides=2)(x)
    x = Conv2D(64, (3, 3), **kwargs)(x)
    x = Conv2D(64, (3, 3), **kwargs)(x)
    x = BatchNormalization()(x)
    if with_dropout: x = Dropout(conv_drop, noise_shape=(None, 1, 1, int(x.shape[-1])))(x)

    x = Conv2D(64, (2, 2), **kwargs, strides=2)(x)
    x = Conv2D(64, (3, 3), **kwargs)(x)
    x = Conv2D(64, (3, 3), **kwargs)(x)
    x = BatchNormalization()(x)
    if with_dropout: x = Dropout(conv_drop, noise_shape=(None, 1, 1, int(x.shape[-1])))(x)

    h = MaxPooling2D(pool_size=(1, int(x.shape[2])))(x)
    h = Flatten()(h)
    if with_dropout: h = Dropout(dense_drop)(h)
    h = Dense(16, activation='relu')(h)

    v = MaxPooling2D(pool_size=(int(x.shape[1]), 1))(x)
    v = Flatten()(v)
    if with_dropout: v = Dropout(dense_drop)(v)
    v = Dense(16, activation='relu')(v)

    x = Concatenate()([h,v])
    if with_dropout: x = Dropout(0.5)(x)
    x = Dense(4, activation='linear')(x)
    return Model(inp,x)

model = build_model(with_dropout=True)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 64) 5248        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128, 128, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 64)   16448       dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 64)   36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 64)   36928       conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 64, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   16448       dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 64)   16448       dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 64)   36928       conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   36928       conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 64)     16448       dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 64)     36928       conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 64)     36928       conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 8, 8, 64)     256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 64)     0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 4, 4, 64)     16448       dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 64)     36928       conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 4, 4, 64)     36928       conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 4, 4, 64)     256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 4, 4, 64)     0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 4, 1, 64)     0           dropout_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 1, 4, 64)     0           dropout_5[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 256)          0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 256)          0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 256)          0           flatten[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 256)          0           flatten_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 16)           4112        dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 16)           4112        dropout_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32)           0           dense[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 32)           0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 4)            132         dropout_8[0][0]
# ==================================================================================================
# Total params: 503,588
# Trainable params: 502,820
# Non-trainable params: 768
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

for num in range(1, 4):
    model_name = 'cropping-%01d.h5' % num
    print(model_name)
    model.compile(Adam(learning_rate=0.032), loss='mean_squared_error')
    model.fit(
        TrainingData(), epochs=50, max_queue_size=12, workers=4, verbose=1,
        validation_data=(val_a, val_b),
        callbacks=[
            EarlyStopping(monitor='val_loss', patience=9, min_delta=0.1, verbose=1),
            ReduceLROnPlateau(monitor='val_loss', patience=3, min_delta=0.1, factor=0.25, min_lr=0.002, verbose=1),
            ModelCheckpoint(model_name, save_best_only=True, save_weights_only=True),
        ])
    model.load_weights(model_name)
    model.evaluate(val_a, val_b, verbose=0)
# Out:
# cropping-1.h5
# Epoch 1/50
# C:\Users\scott\AppData\Local\Temp/ipykernel_34784/685740430.py:78: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y,x,_ = trans.dot([y,x,1]).astype(np.int)
# 500/500 [==============================] - 48s 94ms/step - loss: 235.6093 - val_loss: 111.3141
# Epoch 2/50
# 500/500 [==============================] - 28s 55ms/step - loss: 203.1017 - val_loss: 120.7161
# Epoch 3/50
# 500/500 [==============================] - 28s 55ms/step - loss: 170.8065 - val_loss: 89.1034
# Epoch 4/50
# 500/500 [==============================] - 29s 58ms/step - loss: 143.6080 - val_loss: 91.9092
# Epoch 5/50
# 500/500 [==============================] - 28s 55ms/step - loss: 120.8063 - val_loss: 64.6739
# Epoch 6/50
# 500/500 [==============================] - 27s 53ms/step - loss: 100.5212 - val_loss: 48.6348
# Epoch 7/50
# 500/500 [==============================] - 28s 55ms/step - loss: 87.8185 - val_loss: 57.4375
# Epoch 8/50
# 500/500 [==============================] - 29s 57ms/step - loss: 77.4424 - val_loss: 45.2200
# Epoch 9/50
# 500/500 [==============================] - 29s 57ms/step - loss: 69.9898 - val_loss: 50.1481
# Epoch 10/50
# 500/500 [==============================] - 28s 55ms/step - loss: 64.8670 - val_loss: 49.0052
# Epoch 11/50
# 500/500 [==============================] - 28s 56ms/step - loss: 63.3720 - val_loss: 50.4802
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00800000037997961.
# Epoch 12/50
# 500/500 [==============================] - 29s 57ms/step - loss: 54.2340 - val_loss: 38.0787
# Epoch 13/50
# 500/500 [==============================] - 29s 57ms/step - loss: 52.5738 - val_loss: 33.0677
# Epoch 14/50
# 500/500 [==============================] - 29s 57ms/step - loss: 50.9987 - val_loss: 34.5927
# Epoch 15/50
# 500/500 [==============================] - 29s 57ms/step - loss: 51.0649 - val_loss: 35.3400
# Epoch 16/50
# 500/500 [==============================] - 29s 57ms/step - loss: 50.0423 - val_loss: 40.8996
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0020000000949949026.
# Epoch 17/50
# 500/500 [==============================] - 29s 57ms/step - loss: 48.1152 - val_loss: 36.0315
# Epoch 18/50
# 500/500 [==============================] - 29s 58ms/step - loss: 47.5558 - val_loss: 33.3727
# Epoch 19/50
# 500/500 [==============================] - 29s 58ms/step - loss: 46.2687 - val_loss: 33.3327
# Epoch 20/50
# 500/500 [==============================] - 29s 57ms/step - loss: 47.6052 - val_loss: 33.6583
# Epoch 21/50
# 500/500 [==============================] - 30s 59ms/step - loss: 46.7773 - val_loss: 33.3712
# Epoch 22/50
# 500/500 [==============================] - 29s 58ms/step - loss: 46.6680 - val_loss: 34.2046
# Epoch 00022: early stopping
# cropping-2.h5
# Epoch 1/50
# 500/500 [==============================] - 31s 59ms/step - loss: 60.3862 - val_loss: 39.9043
# Epoch 2/50
# 500/500 [==============================] - 29s 58ms/step - loss: 58.9131 - val_loss: 36.7985
# Epoch 3/50
# 500/500 [==============================] - 29s 57ms/step - loss: 58.6561 - val_loss: 41.6478
# Epoch 4/50
# 500/500 [==============================] - 29s 58ms/step - loss: 57.2071 - val_loss: 34.5511
# Epoch 5/50
# 500/500 [==============================] - 31s 61ms/step - loss: 56.9605 - val_loss: 40.7119
# Epoch 6/50
# 500/500 [==============================] - 29s 57ms/step - loss: 55.6270 - val_loss: 32.5466
# Epoch 7/50
# 500/500 [==============================] - 29s 57ms/step - loss: 55.4706 - val_loss: 43.1900
# Epoch 8/50
# 500/500 [==============================] - 30s 59ms/step - loss: 55.2715 - val_loss: 35.5152
# Epoch 9/50
# 500/500 [==============================] - 30s 58ms/step - loss: 55.0098 - val_loss: 49.6047
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00800000037997961.
# Epoch 10/50
# 500/500 [==============================] - 31s 61ms/step - loss: 45.5155 - val_loss: 31.6319
# Epoch 11/50
# 500/500 [==============================] - 30s 59ms/step - loss: 45.4552 - val_loss: 29.2816
# Epoch 12/50
# 500/500 [==============================] - 30s 58ms/step - loss: 44.3767 - val_loss: 27.6188
# Epoch 13/50
# 500/500 [==============================] - 28s 56ms/step - loss: 44.3359 - val_loss: 29.0010
# Epoch 14/50
# 500/500 [==============================] - 29s 57ms/step - loss: 43.5097 - val_loss: 30.0153
# Epoch 15/50
# 500/500 [==============================] - 30s 59ms/step - loss: 43.8901 - val_loss: 30.3496
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0020000000949949026.
# Epoch 16/50
# 500/500 [==============================] - 28s 56ms/step - loss: 42.1444 - val_loss: 29.2460
# Epoch 17/50
# 500/500 [==============================] - 29s 57ms/step - loss: 41.8402 - val_loss: 28.6584
# Epoch 18/50
# 500/500 [==============================] - 29s 57ms/step - loss: 41.0223 - val_loss: 28.8985
# Epoch 19/50
# 500/500 [==============================] - 29s 57ms/step - loss: 40.9008 - val_loss: 30.0033
# Epoch 20/50
# 500/500 [==============================] - 29s 57ms/step - loss: 41.2834 - val_loss: 29.4243
# Epoch 21/50
# 500/500 [==============================] - 29s 58ms/step - loss: 41.3872 - val_loss: 27.4969
# Epoch 22/50
# 500/500 [==============================] - 29s 57ms/step - loss: 40.7705 - val_loss: 27.7873
# Epoch 23/50
# 500/500 [==============================] - 28s 56ms/step - loss: 40.8139 - val_loss: 29.8702
# Epoch 24/50
# 500/500 [==============================] - 27s 54ms/step - loss: 40.8121 - val_loss: 30.5628
# Epoch 25/50
# 500/500 [==============================] - 26s 52ms/step - loss: 41.3626 - val_loss: 28.1246
# Epoch 26/50
# 500/500 [==============================] - 25s 50ms/step - loss: 40.6920 - val_loss: 29.2190
# Epoch 27/50
# 500/500 [==============================] - 26s 51ms/step - loss: 41.4557 - val_loss: 30.5542
# Epoch 28/50
# 500/500 [==============================] - 26s 51ms/step - loss: 40.3936 - val_loss: 30.0350
# Epoch 29/50
# 500/500 [==============================] - 25s 50ms/step - loss: 40.7121 - val_loss: 28.1886
# Epoch 30/50
# 500/500 [==============================] - 25s 50ms/step - loss: 40.5045 - val_loss: 27.9495
# Epoch 00030: early stopping
# cropping-3.h5
# Epoch 1/50
# 500/500 [==============================] - 27s 51ms/step - loss: 51.4631 - val_loss: 36.2791
# Epoch 2/50
# 500/500 [==============================] - 25s 50ms/step - loss: 53.6775 - val_loss: 36.4217
# Epoch 3/50
# 500/500 [==============================] - 25s 50ms/step - loss: 51.2488 - val_loss: 36.4793
# Epoch 4/50
# 500/500 [==============================] - 26s 51ms/step - loss: 51.3284 - val_loss: 36.9645
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00800000037997961.
# Epoch 5/50
# 500/500 [==============================] - 27s 53ms/step - loss: 44.4687 - val_loss: 29.6382
# Epoch 6/50
# 500/500 [==============================] - 28s 55ms/step - loss: 42.7755 - val_loss: 31.3069
# Epoch 7/50
# 500/500 [==============================] - 30s 60ms/step - loss: 42.3588 - val_loss: 29.1794
# Epoch 8/50
# 500/500 [==============================] - 28s 55ms/step - loss: 42.1860 - val_loss: 29.5423
# Epoch 9/50
# 500/500 [==============================] - 26s 52ms/step - loss: 42.4353 - val_loss: 30.5872
# Epoch 10/50
# 500/500 [==============================] - 26s 52ms/step - loss: 41.9862 - val_loss: 30.6335
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0020000000949949026.
# Epoch 11/50
# 500/500 [==============================] - 26s 51ms/step - loss: 40.9036 - val_loss: 28.1003
# Epoch 12/50
# 500/500 [==============================] - 25s 50ms/step - loss: 40.5967 - val_loss: 29.3989
# Epoch 13/50
# 500/500 [==============================] - 25s 50ms/step - loss: 40.1241 - val_loss: 28.9948
# Epoch 14/50
# 500/500 [==============================] - 25s 50ms/step - loss: 40.1172 - val_loss: 28.3294
# Epoch 15/50
# 500/500 [==============================] - 25s 50ms/step - loss: 40.0495 - val_loss: 27.5030
# Epoch 16/50
# 500/500 [==============================] - 25s 50ms/step - loss: 39.5430 - val_loss: 30.1192
# Epoch 17/50
# 500/500 [==============================] - 26s 51ms/step - loss: 39.6914 - val_loss: 29.1592
# Epoch 18/50
# 500/500 [==============================] - 27s 54ms/step - loss: 39.6407 - val_loss: 29.6213
# Epoch 19/50
# 500/500 [==============================] - 27s 53ms/step - loss: 39.3481 - val_loss: 28.5157
# Epoch 20/50
# 500/500 [==============================] - 26s 51ms/step - loss: 39.8786 - val_loss: 28.4440
# Epoch 21/50
# 500/500 [==============================] - 26s 51ms/step - loss: 39.2577 - val_loss: 28.8797
# Epoch 22/50
# 500/500 [==============================] - 26s 51ms/step - loss: 40.2130 - val_loss: 28.1032
# Epoch 23/50
# 500/500 [==============================] - 26s 51ms/step - loss: 39.8117 - val_loss: 28.9256
# Epoch 24/50
# 500/500 [==============================] - 26s 51ms/step - loss: 39.7475 - val_loss: 29.7056
# Epoch 00024: early stopping

# %%
model.load_weights('cropping-1.h5')
loss1 = model.evaluate(val_a, val_b, verbose=0)
model.load_weights('cropping-2.h5')
loss2 = model.evaluate(val_a, val_b, verbose=0)
model.load_weights('cropping-3.h5')
loss3 = model.evaluate(val_a, val_b, verbose=0)
model_name = 'cropping-1.h5'
if loss2 <= loss1 and loss2 < loss3: model_name = 'cropping-2.h5'
if loss3 <= loss1 and loss3 <= loss2: model_name = 'cropping-3.h5'
model.load_weights(model_name)
loss1, loss2, loss3, model_name
# Out:
# (33.06773376464844, 27.496864318847656, 27.502971649169922, 'cropping-2.h5')

# %%
model2 = build_model(with_dropout=False)
model2.load_weights(model_name)
model2.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 64) 5248        input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 128, 128, 64) 256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 64, 64)   16448       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 64)   36928       conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 64, 64)   36928       conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 64)   256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 32, 64)   16448       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 32, 64)   36928       conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 64)   36928       conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 16, 16, 64)   16448       batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 16, 16, 64)   36928       conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 64)   36928       conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 64)   256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 8, 64)     16448       batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 8, 8, 64)     36928       conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 8, 8, 64)     36928       conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 64)     256         conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 4, 4, 64)     16448       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 4, 4, 64)     36928       conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 4, 4, 64)     36928       conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 4, 4, 64)     256         conv2d_33[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 4, 1, 64)     0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 1, 4, 64)     0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 256)          0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 256)          0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 16)           4112        flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 16)           4112        flatten_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32)           0           dense_3[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 4)            132         concatenate_1[0][0]
# ==================================================================================================
# Total params: 503,588
# Trainable params: 502,820
# Non-trainable params: 768
# __________________________________________________________________________________________________

# %%
model2.compile(Adam(lr=0.002), loss='mean_squared_error')
model2.evaluate(val_a, val_b, verbose=0)
# Out:
# 27.496864318847656

# %%
# Recompute the mean and variance running average without dropout
for layer in model2.layers:
    if not isinstance(layer, BatchNormalization):
        layer.trainable = False
model2.compile(Adam(lr=0.002), loss='mean_squared_error')
model2.fit_generator(TrainingData(), epochs=1, max_queue_size=12, workers=6, verbose=1, validation_data=(val_a, val_b))
for layer in model2.layers:
    if not isinstance(layer, BatchNormalization):
        layer.trainable = True
model2.compile(Adam(lr=0.002), loss='mean_squared_error')
model2.save('cropping.model')
# Out:
# C:\Users\scott\anaconda3\envs\fourthbrain_tf_2\lib\site-packages\tensorflow\python\keras\engine\training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# C:\Users\scott\AppData\Local\Temp/ipykernel_34784/685740430.py:78: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y,x,_ = trans.dot([y,x,1]).astype(np.int)
# 500/500 [==============================] - 22s 42ms/step - loss: 6.9494 - val_loss: 23.3260
# INFO:tensorflow:Assets written to: cropping.model\assets

# %%
model2.evaluate(val_a, val_b, verbose=0)
# Out:
# 23.32601547241211

# %%
images = []
for i,(p,coords) in enumerate(val[:25]):
    a         = val_a[i:i+1]
    rect1     = val_b[i]
    rect2     = model2.predict(a).squeeze()
    img       = array_to_img(a[0]).convert('RGB')
    draw      = Draw(img)
    draw.rectangle(rect1, outline='red')
    draw.rectangle(rect2, outline='yellow')
    images.append(img)
show_whale(images)

# %%
from pandas import read_csv

tagged = [p for _,p,_ in read_csv('./input/data/train.csv').to_records()]
submit = [p for _,p,_ in read_csv('./input/data/sample_submission.csv').to_records()]
join = tagged + submit
len(join)
# Out:
# 25460

# %%
# If the picture is part of the bounding box dataset, use the golden value.
p2bb = {}
for i,(p,coords) in enumerate(data): p2bb[p] = bounding_rectangle(coords)
len(p2bb)
# Out:
# 1200

# %%
# For other pictures, evaluate the model.
p2bb = {}
for p in tqdm_notebook(join):
    if p not in p2bb:
        img,trans         = read_for_validation(p)
        a                 = np.expand_dims(img, axis=0)
        x0, y0, x1, y1    = model2.predict(a).squeeze()
        (u0, v0),(u1, v1) = coord_transform([(x0,y0),(x1,y1)], trans)
        p2bb[p]           = (u0, v0, u1, v1)
# Out:
# C:\Users\scott\AppData\Local\Temp/ipykernel_34784/3379219210.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for p in tqdm_notebook(join):
#   0%|          | 0/25460 [00:00<?, ?it/s]
# C:\Users\scott\AppData\Local\Temp/ipykernel_34784/685740430.py:78: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y,x,_ = trans.dot([y,x,1]).astype(np.int)

# %%
import pickle

with open('bounding-box.pickle', 'wb') as f: pickle.dump(p2bb, f)

# %%
samples = []
for p in tagged[:25]:
    img         = read_raw_image(p).convert('RGB')
    draw        = Draw(img)
    x0,y0,x1,y1 = p2bb[p]
    draw.line([(x0, y0),(x0,y1),(x1,y1),(x1,y0),(x0,y0)], fill='yellow', width=6)
    samples.append(img)
show_whale(samples)
